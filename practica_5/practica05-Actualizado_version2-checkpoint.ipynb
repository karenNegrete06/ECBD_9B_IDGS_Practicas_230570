# %% [markdown]
# # Practica 05: Analisis de Datos Exploratorio con Python y Jupiter Notebook

# %% [markdown]
# *Programa de Estudios:* Ingeniería en Desarrollo y Gestón de Software \
# *Asignatura:* Extracción de Conocimiento en Bases de Datos \
# *Docente:* M.T.I Marco A. Ramírez Hernández \
# *Periodo:* Mayo - Agosto 23026

# %% [markdown]
# ### Unidad 2: Preparación de los Datos

# %% [markdown]
# **Nombre del Estudiante:** Karen Lizbeth Negrete Hernández\
# **Matricula:** 230570\
# **Grado y Grupo:** 9 B IDGS

# %% [markdown]
# El estudiante practicará como realizar un analasis exploratorio de datos (EDA), utilizando el lenguaje de
# programación de Python, y librerias comunes para la carga, manipulación, análisis y visualización prevla de un
# conjunto de datos (Dataset), para esta práctica se utilizarán las librerlas de:
#
# - Pandas
# - Numpy
# - Seaborn
# - Matplotlib

# %% [markdown]
# 1. Importar las librerias necesarlas para realizar el EDA
# Comenzamos por importar la libreria que nos permitirá manipula los datos del dataset extraidos de una fuente de
# datos (datasource)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Creamos un DataFrame, leyendo el archivo delimitado por comas (.CSV)

# %%
pokemons=pd.read_csv('./Pokemon.csv')

# %%
pokemonsEvo=pd.read_csv('./Pokemon_Evolution_Stages_completo.csv')

# %% [markdown]
# 3. Imprimimos el resultado de la lectura
# Este comando imprime en una tabla las columnas y las filas del dataframe, siempre de manera estándar nos mostrara
# los primeros 5 y los últimos 5 registros del dataframe.

# %%
pokemons
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3               Venusaur    Grass  Poison    525  80      82       83
# 4      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 800  719                Diancie     Rock   Fairy    600  50     100      150
# 801  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 802  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 803  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 804  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemonsEvo
# Out:
#        #                   Name      Type 1  Type 2  Total  HP  Attack  \
# 0      1              Bulbasaur       Grass  Poison    318  45      49
# 1      2                Ivysaur       Grass  Poison    405  60      62
# 2      3               Venusaur       Grass  Poison    525  80      82
# 3      3               Venusaur       Grass  Poison    525  80      82
# 4      3  VenusaurMega Venusaur       Grass  Poison    625  80     100
# ..   ...                    ...         ...     ...    ...  ..     ...
# 805  722               Magearna  Artificial   Fairy    600  80      95
# 806  723             Type: Null  Artificial     NaN    534  95      95
# 807  724               Silvally  Artificial     NaN    570  95      95
# 808  725                 Cosmog  Artificial     NaN    200  43      29
# 809  726                Cosmoem  Artificial     NaN    400  43      29
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Evolution
# ...

# %% [markdown]
# Ejercicio 01: Obtener 50 registros

# %%
pokemons.head(50)
# Out:
#      #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0    1                  Bulbasaur     Grass  Poison    318   45      49
# 1    2                    Ivysaur     Grass  Poison    405   60      62
# 2    3                   Venusaur     Grass  Poison    525   80      82
# 3    3                   Venusaur     Grass  Poison    525   80      82
# 4    3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 5    4                 Charmander      Fire     NaN    309   39      52
# 6    5                 Charmeleon      Fire     NaN    405   58      64
# 7    6                  Charizard      Fire  Flying    534   78      84
# 8    6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 9    6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 10   7                   Squirtle     Water     NaN    314   44      48
# 11   8                  Wartortle     Water     NaN    405   59      63
# ...

# %% [markdown]
# 4. Obtener una muestra aleatoria de registros del dateframe usuando el método .sample

# %% [markdown]
# Como parámetro de entrada podemos definir un entorno que determina el tamaño de la muestra

# %%
pokemons.sample(7) ## Obtiene una muestra de 7 pokemones aleatorio
# Out:
#        #        Name   Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 240  220      Swinub      Ice  Ground    250  50      50       40       30
# 471  421     Cherrim    Grass     NaN    450  70      60       70       87
# 92    83  Farfetch'd   Normal  Flying    352  52      65       55       58
# 72    65    Alakazam  Psychic     NaN    500  55      50       45      135
# 44    38   Ninetales     Fire     NaN    505  73      76       75       81
# 50    44       Gloom    Grass  Poison    395  60      65       70       85
# 205  188    Skiploom    Grass  Flying    340  55      45       50       45
#
#      Sp. Def  Speed  Generation  Legendary
# 240       30     50           2      False
# 471       78     85           4      False
# 92        62     60           1      False
# 72        95    120           1      False
# 44       100    100           1      False
# 50        75     40           1      False
# 205       65     80           2      False

# %% [markdown]
# 5.- Obtener una muestra de rangos definidos usando .iloc

# %%
pokemons_100_to_200 = pokemons.iloc[100:200]
pokemons_100_to_200
# Out:
#        #                   Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 100   91               Cloyster     Water     Ice    525  50      95      180
# 101   92                 Gastly     Ghost  Poison    310  30      35       30
# 102   93                Haunter     Ghost  Poison    405  45      50       45
# 103   94                 Gengar     Ghost  Poison    500  60      65       60
# 104   94      GengarMega Gengar     Ghost  Poison    600  60      65       80
# ..   ...                    ...       ...     ...    ...  ..     ...      ...
# 195  179                 Mareep  Electric     NaN    280  55      40       40
# 196  180                Flaaffy  Electric     NaN    365  70      55       55
# 197  181               Ampharos  Electric     NaN    510  90      75       85
# 198  181  AmpharosMega Ampharos  Electric  Dragon    610  90      95      105
# 199  182              Bellossom     Grass     NaN    490  75      80       95
#
# ...

# %% [markdown]
# 6.- Como saber las columnas o atributos tiene el datafame

# %%
pokemons.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# | Campo | Descripción |
# |--------|-------------|
# | **#** | El ID o número de identificación del Pokémon. |
# | **Name:** | El nombre del Pokémon. |
# | **Type 1:** | Se refiere a las propiedades elementales (tipos) asociadas tanto al Pokémon como a sus movimientos. |
# | **Type 2:** | Los Pokémon pueden tener hasta dos tipos (Pokémon de tipo dual); los movimientos solo pueden tener uno. |
# | **Total:** | Representa la suma de todos los stats, lo que da una idea de qué tan fuerte es el Pokémon. |
# | **HP:** | (Puntos de Salud) Es qué tanto aguante tiene un Pokémon antes de que lo dejen fuera de combate (se desmaye). |
# | **Attack:** | La fuerza de los ataques físicos del Pokémon. |
# | **Defense:** | Qué tanto aguanta el Pokémon contra los ataques físicos del rival. |
# | **Evolution_Level:** | Nivel de evolución del Pokémon. |
# | **Sp. Atk:** | Ataque Especial: el poder de los movimientos especiales del Pokémon. |
# | **Sp. Def:** | Defensa Especial: qué tan resistente es el Pokémon ante los ataques especiales. |
# | **Speed:** | Velocidad del Pokémon; el que tenga más velocidad es el que ataca primero. |
# | **Generation:** | Se refiere a la generación de la serie de juegos a la que pertenece. |
# | **Legendary:** | Indica si el Pokémon es legendario o no (son muy raros y poderosos). Es un valor booleano (sí/no). |

# %%
pokemonsEvo.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Evolution'],
#       dtype='object')

# %% [markdown]
# | Campo | Descripción |
# |--------|-------------|
# | **#** | El ID o número de identificación del Pokémon. |
# | **Name:** | El nombre del Pokémon. |
# | **Type 1:** | Se refiere a las propiedades elementales (tipos) asociadas tanto al Pokémon como a sus movimientos. |
# | **Type 2:** | Los Pokémon pueden tener hasta dos tipos (Pokémon de tipo dual); los movimientos solo pueden tener uno. |
# | **Total:** | Representa la suma de todos los stats, lo que da una idea de qué tan fuerte es el Pokémon. |
# | **HP:** | (Puntos de Salud) Es qué tanto aguante tiene un Pokémon antes de que lo dejen fuera de combate (se desmaye). |
# | **Attack:** | La fuerza de los ataques físicos del Pokémon. |
# | **Defense:** | Qué tanto aguanta el Pokémon contra los ataques físicos del rival. |
# | **Evolution_Level:** | Nivel de evolución del Pokémon. |
# | **Sp. Atk:** | Ataque Especial: el poder de los movimientos especiales del Pokémon. |
# | **Sp. Def:** | Defensa Especial: qué tan resistente es el Pokémon ante los ataques especiales. |
# | **Speed:** | Velocidad del Pokémon; el que tenga más velocidad es el que ataca primero. |
# | **Generation:** | Se refiere a la generación de la serie de juegos a la que pertenece. |
# | **Legendary:** | Indica si el Pokémon es legendario o no (son muy raros y poderosos). Es un valor booleano (sí/no). |
# | **Evolution:** | Indica el número de evoluciones que tiene el Pokémon. |

# %% [markdown]
# 7. Explorar la composición y ausencia de datos (METADATA) CON **.info**

# %% [markdown]
# La libreria de pandas, incluye un método que nos permite evaluar el tipo de datos y su composicion y ausencia

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 805 entries, 0 to 804
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           805 non-null    int64
#  1   Name        805 non-null    object
#  2   Type 1      805 non-null    object
#  3   Type 2      416 non-null    object
#  4   Total       805 non-null    int64
#  5   HP          805 non-null    int64
#  6   Attack      805 non-null    int64
#  7   Defense     805 non-null    int64
#  8   Sp. Atk     805 non-null    int64
#  9   Sp. Def     805 non-null    int64
#  10  Speed       805 non-null    int64
#  11  Generation  805 non-null    int64
#  12  Legendary   805 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 76.4+ KB

# %%
pokemonsEvo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 0 to 809
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           810 non-null    int64
#  1   Name        810 non-null    object
#  2   Type 1      810 non-null    object
#  3   Type 2      417 non-null    object
#  4   Total       810 non-null    int64
#  5   HP          810 non-null    int64
#  6   Attack      810 non-null    int64
#  7   Defense     810 non-null    int64
#  8   Sp. Atk     810 non-null    int64
#  9   Sp. Def     810 non-null    int64
#  10  Speed       810 non-null    int64
#  11  Generation  810 non-null    int64
#  12  Legendary   810 non-null    bool
#  13  Evolution   810 non-null    int64
# dtypes: bool(1), int64(10), object(3)
# memory usage: 83.2+ KB

# %% [markdown]
# 8. Limpíeza de Datos

# %% [markdown]
# Dependiendo del Objetivo del analisis algunas columnas o registro no serán necesarias en nuestro dataframe, en este caso omitieremos los datos vacíos, por lo que eliminaremos la columna 'Type 2', y renombraremos la columna 'Type 1'por 'Type'.

# %%
pokemons=pokemons.drop(columns=['Type 2'], errors='ignore').rename(columns={'Type 1': 'Type'})

# %%
pokemons
# Out:
#        #                   Name     Type  Total  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur    Grass    318  45      49       49       65
# 1      2                Ivysaur    Grass    405  60      62       63       80
# 2      3               Venusaur    Grass    525  80      82       83      100
# 3      3               Venusaur    Grass    525  80      82       83      100
# 4      3  VenusaurMega Venusaur    Grass    625  80     100      123      122
# ..   ...                    ...      ...    ...  ..     ...      ...      ...
# 800  719                Diancie     Rock    600  50     100      150      100
# 801  719    DiancieMega Diancie     Rock    700  50     160      110      160
# 802  720    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 803  720     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 804  721              Volcanion     Fire    600  80     110      120      130
#
# ...

# %%
pokemonsEvo=pokemonsEvo.drop(columns=['Type 2'], errors='ignore').rename(columns={'Type 1': 'Type'})

# %%
pokemonsEvo
# Out:
#        #                   Name        Type  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur       Grass    318  45      49       49
# 1      2                Ivysaur       Grass    405  60      62       63
# 2      3               Venusaur       Grass    525  80      82       83
# 3      3               Venusaur       Grass    525  80      82       83
# 4      3  VenusaurMega Venusaur       Grass    625  80     100      123
# ..   ...                    ...         ...    ...  ..     ...      ...
# 805  722               Magearna  Artificial    600  80      95      115
# 806  723             Type: Null  Artificial    534  95      95       95
# 807  724               Silvally  Artificial    570  95      95       95
# 808  725                 Cosmog  Artificial    200  43      29       31
# 809  726                Cosmoem  Artificial    400  43      29      131
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Evolution
# ...

# %% [markdown]
# 9. Visualizacio de los primeros datos usando el metodo **.head**

# %%
pokemons.head()
# Out:
#    #                   Name   Type  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass    318  45      49       49       65
# 1  2                Ivysaur  Grass    405  60      62       63       80
# 2  3               Venusaur  Grass    525  80      82       83      100
# 3  3               Venusaur  Grass    525  80      82       83      100
# 4  3  VenusaurMega Venusaur  Grass    625  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      100     80           1      False
# 4      120     80           1      False

# %% [markdown]
# **Ejercicio 03:** Muestra los ultimos 10 regisros del dataframe

# %%
pokemons.tail(10)
# Out:
#        #                 Name     Type  Total   HP  Attack  Defense  Sp. Atk  \
# 795  714               Noibat   Flying    245   40      30       35       45
# 796  715              Noivern   Flying    535   85      70       80       97
# 797  716              Xerneas    Fairy    680  126     131       95      131
# 798  717              Yveltal     Dark    680  126     131       95      131
# 799  718     Zygarde50% Forme   Dragon    600  108     100      121       81
# 800  719              Diancie     Rock    600   50     100      150      100
# 801  719  DiancieMega Diancie     Rock    700   50     160      110      160
# 802  720  HoopaHoopa Confined  Psychic    600   80     110       60      150
# 803  720   HoopaHoopa Unbound  Psychic    680   80     160       60      170
# 804  721            Volcanion     Fire    600   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795       40     55           6      False
# ...

# %% [markdown]
# 10. Estadisitcas basicas del Dataframe

# %% [markdown]
# Pandas permite emitir un reporte de estadistica basica(medidas de tendencia) sobre datos cuantitativos usando el comando **.describe**

# %%
pokemons.describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count  805.000000  805.000000  805.000000  805.000000  805.000000  805.000000
# mean   362.214907  435.362733   69.351553   79.075776   73.844720   72.829814
# std    208.416447  119.985831   25.510351   32.520456   31.131673   32.643439
# min      1.000000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    184.000000  330.000000   50.000000   55.000000   50.000000   50.000000
# 50%    364.000000  450.000000   65.000000   75.000000   70.000000   65.000000
# 75%    538.000000  515.000000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.000000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  805.000000  805.000000  805.000000
# mean    71.967702   68.293168    3.319255
# std     27.794716   29.046600    1.660543
# min     20.000000    5.000000    1.000000
# 25%     50.000000   45.000000    2.000000
# ...

# %% [markdown]
# 11. Calcular el total de datos no duplicados (unicos)
#
# usaremos **.len()** como funcion para calcular la longitud del dataframe y **.unique()** para excluir los duplicados
#
# **NOTA** No considerr ID como atrbuto llave primaria, si no el total de columnas como un solo elemento u objeto.

# %% [markdown]
# Obteniendo los valores unicos por columna en este caso en la columna "Name"

# %%
len(pokemons.Name.unique())
# Out:
# 800

# %% [markdown]
# Obteniendo el total de objetos (Conjunto de atributos, estrictamente iguales) unicos.

# %%
total_unicos= len(pokemons.drop_duplicates())
total_unicos
# Out:
# 802

# %% [markdown]
# **Ejercicio 04:** Obtener el total de IDs unicos en el dataset

# %%
total_ids_unicos = pokemons['#'].nunique()
total_ids_unicos
# Out:
# 721

# %% [markdown]
# **Ejercicio 05:** Obtener el total de tipos unicos de Pokemones

# %%
total_ids_unicos = pokemons['Type'].nunique()
total_ids_unicos
# Out:
# 18

# %% [markdown]
# 12. Contabilizacion de Datos por Atributo

# %% [markdown]
# Pandas nos permite agrupar los datos por atributo y contabilizar los totales usando .value_conunts() ¿Cuantos Pokemones hay por Generacion?

# %%
pokemons['Generation'].value_counts()
# Out:
# Generation
# 1    168
# 5    165
# 3    161
# 4    123
# 2    106
# 6     82
# Name: count, dtype: int64

# %% [markdown]
# 13. Grafica de número de Pokemones agrupados por el atributo de **Generación**

# %% [markdown]
# El método **countplot** ofrece un constructor donde se puede configurar la gráfica

# %% [markdown]
# La libreria de **Matplot** (nombrada pit), permite poner un texto de título
# ¿Cuántos pokemones hay por generación?

# %% [markdown]
# **Ejercicio 06**: Obtener el total de pokemonespor generación con el dataset modificando

# %%
sns.countplot(x='Generation',hue="Generation",data=pokemons,palette='nipy_spectral')
plt.title('Numero de pokemones agrupados por generacion')
# Out:
# Text(0.5, 1.0, 'Numero de pokemones agrupados por generacion')

# %% [markdown]
# **Ejercicio 7:** Dibujar la grafica por generación obteniendo los datos de (pokemonEvo)

# %%
sns.countplot(x='Generation',hue="Generation",data=pokemonsEvo,palette='nipy_spectral')
plt.title('Numero de pokemones agrupados por generacion')
# Out:
# Text(0.5, 1.0, 'Numero de pokemones agrupados por generacion')

# %% [markdown]
# 14. Conteo de pokemones por atributo **Tipo** utilizamos **.value_counts()** para realizar un conteo de los valores especializados en el atributo accedido anterior (Type), permitiendo hacer un conteo de las apariciones de ellos

# %%
pokemons.Type.value_counts()
# Out:
# Type
# Water       113
# Normal       99
# Grass        71
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Fighting     28
# Poison       28
# Steel        27
# Ice          25
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %% [markdown]
# **Ejercicio 08:** Obtener los totales de los pokemones por tipo del segundo df, ordenados alfabeticamente

# %%
pokemonsEvo.Type.value_counts().sort_index()
# Out:
# Type
# Artificial      5
# Bug            69
# Dark           31
# Dragon         32
# Electric       44
# Fairy          17
# Fighting       28
# Fire           52
# Flying          4
# Ghost          32
# Grass          71
# Ground         32
# Ice            25
# Normal         99
# Poison         28
# Psychic        57
# Rock           44
# Steel          27
# Water         113
# Name: count, dtype: int64

# %% [markdown]
# 15. Conteo de los pokemones por el atributo tipo (Graficado) se usa la libreria **matplot** para configurar el tamaño de la grafica

# %% [markdown]
# **NOTA:** Por el número de pokemones de tipo agua y normal es alto comparado al resto , los pokemones respectivos tendran siempre unn total de stats as altos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

order = pokemons['Type'].value_counts().index

plt.figure(figsize=(12, 6))

ax = sns.countplot(
    data=pokemons,
    x='Type',
    hue='Type',
    order=order,
    palette='twilight',
    legend=False
)

for container in ax.containers:
    ax.bar_label(container, padding=3)

plt.title('Número de Pokémon por tipo')
plt.xlabel('Tipo')
plt.ylabel('Cantidad')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# **Ejercicio 09:** Obtener el grafico de total de pokemones por tipo en el DF modificado. Ordenados alfabeticamente

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))

orden = sorted(pokemons['Type'].dropna().unique())

ax = sns.countplot(
    data=pokemons,
    x='Type',
    order=orden,
    hue='Type',
    palette='twilight',
    legend=False
)

for container in ax.containers:
    ax.bar_label(
        container,
        label_type='edge',
        padding=3
    )

plt.title('Total de Pokémon por Tipo (Ordenados Alfabéticamente)')
plt.xlabel('Tipo')
plt.ylabel('Cantidad')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 16.  Revisar distribución de estadisticas con **baxplot**

# %% [markdown]
# Se configura el estilo de la grafica con el metodo **.set_style**

# %% [markdown]
# Ademas se utiliza como data el Dataframe de pokemons , pero excluyendo las columnas **#Total, Generation y legendary**

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.boxplot(data=pokemons.drop(['#','Total','Generation','Legendary'],axis=1),fliersize=3,palette='seismic')
plt.title('Diagramas de caja para estadísticas')
# Out:
# Text(0.5, 1.0, 'Diagramas de caja para estadísticas')

# %% [markdown]
# **Ejercicio 10:** Obtener el grafico de tipo baxplot de 2 dataframe

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))

columnas = sorted(
    pokemonsEvo.drop(['#', 'Total', 'Generation', 'Legendary'], axis=1).columns
)

sns.boxplot(
    data=pokemonsEvo[columnas],
    fliersize=3
)

plt.title('Boxplots for stats (Alphabetically Ordered)')
plt.show()

# %% [markdown]
# 17. Revisar distribución de estadisticas con **vointplot**
#    Se grafican los mismos datos del punto anterior, pero con una grafica y paleta de colores diferentes.

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=pokemons.drop(['#','Total', 'Generation','Legendary'], axis=1))
plt.title('Violinplots para estadisticas ')
# Out:
# Text(0.5, 1.0, 'Violinplots para estadisticas ')

# %% [markdown]
# **Ejercicio 11:** Realizar el Grafico de tipo Violin para el DF modificando, excluyendo tambien evolution level

# %%
plt.figure(figsize=(10,6))
sns.violinplot(
    data=pokemonsEvo.drop(
        ['#','Total','Generation','Legendary','Evolution'],
        axis=1
    ),
    palette='rocket'
)
plt.title('Violinplots para estadisticas ')
plt.tight_layout()
plt.show()

# %% [markdown]
# 18. Pokemonesagrupados por el atributo **Tipo**

# %% [markdown]
# Se utilizan los metodos **.groupby()** y **.sum**

# %%
pokemons.groupby('Type').sum()
# Out:
#               #                                               Name  Total  \
# Type
# Bug       23080  CaterpieMetapodButterfreeWeedleKakunaBeedrillB...  26146
# Dark      14302  UmbreonMurkrowSneaselHoundourHoundoomHoundoomM...  13818
# Dragon    15180  DratiniDragonairDragoniteAltariaAltariaMega Al...  17617
# Electric  15994  PikachuRaichuMagnemiteMagnetonVoltorbElectrode...  19510
# Fairy      7642  ClefairyClefableCleffaTogepiTogeticSnubbullGra...   7024
# Fighting   9881  MankeyPrimeapePrimeapeMachopMachokeMachampHitm...  11699
# Fire      17025  CharmanderCharmeleonCharizardCharizardMega Cha...  23820
# Flying     2711  TornadusIncarnate FormeTornadusTherian FormeNo...   1940
# Ghost     15568  GastlyHaunterGengarGengarMega GengarMisdreavus...  14066
# Grass     24144  BulbasaurIvysaurVenusaurVenusaurVenusaurMega V...  30005
# Ground    11401  SandshrewSandslashDiglettDugtrioCuboneMarowakR...  14000
# Ice       10529  JynxArticunoSwinubPiloswineDelibirdSmoochumSno...  10813
# ...

# %% [markdown]
# **Ejercicio 12:** Elimina la columna nombre (porque es el resultado de la concatenación de todos los de ese tipo a lo de tener un valor cuantitativo),  los ID(#) para el segundo

# %%
df_tipo = pokemonsEvo.groupby('Type').sum(numeric_only=True)
df_tipo
# Out:
#                 #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type
# Artificial   3620   2304   356     343      467      378      467    293
# Bug         23080  26146  3925    4897     4880     3717     4471   4256
# Dark        14302  13818  2071    2740     2177     2314     2155   2361
# Dragon      15180  17617  2666    3588     2764     3099     2843   2657
# Electric    15994  19510  2631    3040     2917     3961     3243   3718
# Fairy        7642   7024  1260    1046     1117     1335     1440    826
# Fighting     9881  11699  1951    2718     1840     1494     1817   1879
# Fire        17025  23820  3635    4408     3524     4627     3755   3871
# Flying       2711   1940   283     315      265      377      290    410
# Ghost       15568  14066  2062    2361     2598     2539     2447   2059
# Grass       24144  30005  4789    5207     5039     5525     5030   4415
# Ground      11401  14000  2361    3064     2715     1807     2008   2045
# ...

# %% [markdown]
# 19. Pokemones agrupados por el atributo tipo, ordenados en orden alfabetico

# %% [markdown]
# Se accede al atributo HP, lo cual permite  visualizar el Tipo, y el HP del pokemon

# %%
pokemons.groupby('Type').sum().HP
# Out:
# Type
# Bug         3925
# Dark        2071
# Dragon      2666
# Electric    2631
# Fairy       1260
# Fighting    1951
# Fire        3635
# Flying       283
# Ghost       2062
# Grass       4789
# Ground      2361
# Ice         1818
# Normal      7683
# Poison      1883
# Psychic     4026
# Rock        2876
# Steel       1761
# Water       8147
# Name: HP, dtype: int64

# %% [markdown]
# 20. Listado de todos los tipos de Pokemon (Sin datos dublicados)

# %%
pokemons['Type'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# 21. Ordenamiento de Tipos(Type) por ordenamiento alfabetico

# %%
list_types=pokemons['Type'].unique().tolist()
list_types.sort()
list_types
# Out:
# ['Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water']

# %% [markdown]
# 22. Calculando los datos para graficación total de estadisticas por cada tipo de pokemon, respetando el orden alfabetico previamente definido

# %%
plt.style.use('seaborn-v0_8-darkgrid')

stats = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

palettes = ['magma', 'ocean', 'vlag', 'copper', 'mako', 'winter']

# Agrupar una sola vez
pokemon_stats = pokemons.groupby('Type')[stats].sum()

fig, axes = plt.subplots(3, 2, figsize=(17, 17))

for ax, stat, palette in zip(axes.flat, stats, palettes):

    sns.barplot(
        data=pokemon_stats.reset_index(),
        x=stat,
        y='Type',
        hue='Type',
        palette=palette,
        dodge=False,
        ax=ax
    )

    # Eliminar leyenda
    if ax.legend_:
        ax.legend_.remove()

    # Etiquetas de valores
    for container in ax.containers:
        ax.bar_label(
            container,
            fmt='%.0f',
            padding=3
        )

    ax.set_title(f'Total de {stat}')
    ax.set_xlabel(stat)
    ax.set_ylabel('Tipo')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ejercicio 13**:  Recalcular los graficos de estadisticas para el segundo DF

# %%
plt.style.use('seaborn-v0_8-darkgrid')

stats = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

palettes = ['magma', 'ocean', 'vlag', 'copper', 'mako', 'winter']

# Agrupar una sola vez
pokemon_stats = pokemonsEvo.groupby('Type')[stats].sum()

fig, axes = plt.subplots(3, 2, figsize=(17, 17))

for ax, stat, palette in zip(axes.flat, stats, palettes):

    sns.barplot(
        data=pokemon_stats.reset_index(),
        x=stat,
        y='Type',
        hue='Type',
        palette=palette,
        dodge=False,
        ax=ax
    )

    # Eliminar leyenda
    if ax.legend_:
        ax.legend_.remove()

    # Agregar etiquetas con valores
    for container in ax.containers:
        ax.bar_label(
            container,
            fmt='%.0f',
            padding=3
        )

    ax.set_title(f'Total de {stat}')
    ax.set_xlabel(stat)
    ax.set_ylabel('Type')

plt.tight_layout()
plt.show()

# %% [markdown]
# 23. Grafica Colmena(Swarmplots) para agrupas las estadisticas.

# %%
k = 1

plt.figure(figsize=(15, 30))

for i in stats:
    plt.subplot(6, 1, k)
    k += 1

    sns.stripplot(
        data=pokemons,
        x='Type',
        y=i,
        hue='Type',
        palette='Dark2',
        legend=False
    )

    plt.title(f'Total of {i} for each type')
    plt.xlabel('Type')
    plt.ylabel(i)
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ejercicio 14:** utiliza el DF modificando para ver el compartimiento de los datos, en este debera aparecer la estadistica "Evolution" y el nuevo tipo "Artificial" ordenados alfabeticamente

# %%
k = 1

plt.figure(figsize=(15, 30))

for i in stats:
    plt.subplot(6, 1, k)
    k += 1

    sns.stripplot(
        data=pokemonsEvo,
        x='Type',
        y=i,
        hue='Type',
        palette='Dark2',
        legend=False
    )

    plt.title(f'Total of {i} for each type')
    plt.xlabel('Type')
    plt.ylabel(i)
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# 24. Graficación de estadistica por tipo

# %%
import math

k = 1
n = len(list_types)
cols = 3
rows = math.ceil(n / cols)

fig, axes = plt.subplots(rows, cols, figsize=(17, rows * 4))
axes = axes.flatten()

for ax, tipo in zip(axes, list_types):

    data_type = pokemons[pokemons['Type'] == tipo]

    totals = (
        data_type
        .sum(numeric_only=True)
        .drop(['#', 'Generation', 'Total'], errors='ignore')
    )

    df_totals = totals.reset_index()
    df_totals.columns = ['Stat', 'Value']

    sns.barplot(
        data=df_totals,
        x='Value',
        y='Stat',
        hue='Stat',
        palette='inferno',
        dodge=False,
        ax=ax
    )

    # Quitar leyenda
    if ax.legend_:
        ax.legend_.remove()

    # Etiquetas de valores
    for container in ax.containers:
        ax.bar_label(
            container,
            fmt='%.0f',
            padding=3
        )

    ax.set_title(tipo)
    ax.set_xlabel('Total')
    ax.set_ylabel('Estadística')

# Ocultar subplots vacíos
for ax in axes[len(list_types):]:
    ax.set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ejercicio 15:** Obtener el conjunto de graficos por cada estadistica por tipo de pokemon en el DF modificado

# %%
import math

list_types = pokemonsEvo['Type'].unique()

k = 1
n = len(list_types)
cols = 3
rows = math.ceil(n / cols)

plt.figure(figsize=(17, rows * 4))

for i in list_types:
    plt.subplot(rows, cols, k)
    k += 1

    data_type = pokemonsEvo[pokemonsEvo['Type'] == i]

    totals = data_type.select_dtypes(include='number').sum()

    totals = totals.drop(
        labels=['#', 'Generation', 'Total'],
        errors='ignore'
    )

    df_totals = totals.reset_index()
    df_totals.columns = ['Stat', 'Value']

    ax = sns.barplot(
        data=df_totals,
        x='Value',
        y='Stat',
        hue='Stat',
        palette='inferno',
        dodge=False
    )

    # Eliminar leyenda
    if ax.legend_:
        ax.legend_.remove()

    # Mostrar valores al final de las barras
    for container in ax.containers:
        ax.bar_label(
            container,
            fmt='%.0f',
            padding=3
        )

    plt.title(i)
    plt.xlabel('Total')
    plt.ylabel('Estadística')

plt.tight_layout()
plt.show()

# %% [markdown]
# 25. Graficas por estadistica

# %%
pok_melt = pd.melt(
    pokemons,
    id_vars=["Name", "Type", "Legendary"],
    value_vars=["HP", "Defense", "Attack", "Sp. Atk", "Sp. Def", "Speed"],  # Fixed typo here
)
pok_melt.head()
# Out:
#                     Name   Type  Legendary variable  value
# 0              Bulbasaur  Grass      False       HP     45
# 1                Ivysaur  Grass      False       HP     60
# 2               Venusaur  Grass      False       HP     80
# 3               Venusaur  Grass      False       HP     80
# 4  VenusaurMega Venusaur  Grass      False       HP     80

# %% [markdown]
# 26. Utilizar graficos e enjambre (SwarmPlota) para representar los valores especificos de las estadisticas por el tipo de  Pokemon

# %%
list_types= pokemons['Type'].unique().tolist()
list_types.sort()

n_cols = 3
n_rows = math.ceil(len(list_types) / n_cols)

fig, axes = plt.subplots(
    n_rows,
    n_cols,
    figsize=(17, 4 * n_rows),
    sharey=True
)

axes = axes.flatten()

for ax, tipo in zip(axes, list_types):

    data_tipo = pok_melt[pok_melt['Type'] == tipo]

    sns.stripplot(
        data=data_tipo,
        x='variable',
        y='value',
        hue='variable',
        palette='gist_stern',
        jitter=True,
        size=4,
        alpha=0.7,
        legend=False,
        ax=ax
    )

    ax.set_title(tipo)
    ax.set_xlabel("")
    ax.set_ylabel("Valor")
    ax.tick_params(axis='x', rotation=45)


for ax in axes[len(list_types):]:
    ax.remove()

plt.tight_layout()
plt.show()

# %% [markdown]
# ***Nota :*** Podemos observar que los Pokémon de tipo Normal, Bicho y Agua tienen más observaciones que el resto.
#
# Pero, ¿qué ocurre si calculamos la media de cada estadística y la representamos gráficamente? En este caso, el pequeño número de algunos Pokémon de diferentes tipos no afectará al análisis.
#
# En primer lugar, veamos la media de las estadísticas agrupadas por el tipo de Pokémon.

# %% [markdown]
# 27. Obtención de los promedios de cada estadistica agrupada por cada tipo de Pokemon

# %%
df=pd.DataFrame()
for i in stats:
    df[i]=pokemons.groupby('Type').describe()[i]['mean']

# %%
df
# Out:
#                  HP      Attack     Defense    Sp. Atk    Sp. Def       Speed
# Type
# Bug       56.884058   70.971014   70.724638  53.869565  64.797101   61.681159
# Dark      66.806452   88.387097   70.225806  74.645161  69.516129   76.161290
# Dragon    83.312500  112.125000   86.375000  96.843750  88.843750   83.031250
# Electric  59.795455   69.090909   66.295455  90.022727  73.704545   84.500000
# Fairy     74.117647   61.529412   65.705882  78.529412  84.705882   48.588235
# Fighting  69.678571   97.071429   65.714286  53.357143  64.892857   67.107143
# Fire      69.903846   84.769231   67.769231  88.980769  72.211538   74.442308
# Flying    70.750000   78.750000   66.250000  94.250000  72.500000  102.500000
# Ghost     64.437500   73.781250   81.187500  79.343750  76.468750   64.343750
# Grass     67.450704   73.338028   70.971831  77.816901  70.845070   62.183099
# Ground    73.781250   95.750000   84.843750  56.468750  62.750000   63.906250
# ...

# %%
df=pd.DataFrame()
for i in stats:
    df[i]=pokemonsEvo.groupby('Type').describe()[i]['mean']

# %%
df
# Out:
#                    HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type
# Artificial  71.200000   68.600000   93.400000  75.600000  93.400000
# Bug         56.884058   70.971014   70.724638  53.869565  64.797101
# Dark        66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon      83.312500  112.125000   86.375000  96.843750  88.843750
# Electric    59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy       74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting    69.678571   97.071429   65.714286  53.357143  64.892857
# Fire        69.903846   84.769231   67.769231  88.980769  72.211538
# Flying      70.750000   78.750000   66.250000  94.250000  72.500000
# Ghost       64.437500   73.781250   81.187500  79.343750  76.468750
# Grass       67.450704   73.338028   70.971831  77.816901  70.845070
# Ground      73.781250   95.750000   84.843750  56.468750  62.750000
# Ice         72.720000   72.240000   71.360000  77.440000  76.040000
# ...

# %% [markdown]
# 28. Identificación de Estadísticas por Tipo

# %% [markdown]
# ***Ejercicio 19:*** Graficar el promedio de las estadisticas para el segundo dataframe

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 20))

k = 1

for i in stats:

    plt.subplot(3, 2, k)
    k += 1

    ax = sns.barplot(
        x=df[i],
        y=df.index,
        hue=df.index,
        palette="plasma",
        legend=False
    )

    plt.title(f"Mean of total {i} for each type")
    plt.xlabel(i)
    plt.ylabel("Type")

plt.tight_layout()
plt.show()

# %% [markdown]
# 29. Graficar promedio de estadisticas por tipo

# %%
# 1. Calculamos promedios usando el dataset correcto
df_pokemonsEvo = pd.DataFrame()

for i in stats:
    df_pokemonsEvo[i] = pokemonsEvo.groupby('Type')[i].mean()

# Eliminamos posibles valores nulos en el índice
df_pokemonsEvo = df_pokemonsEvo[df_pokemonsEvo.index.notnull()]

# 2. Tipos disponibles
list_types_pokemonsEvo = df_pokemonsEvo.index

# 3. Graficamos
k = 1
plt.figure(figsize=(16, 28))

for i in list_types_pokemonsEvo:
    plt.subplot(7, 3, k)

    estadisticas = df_pokemonsEvo.loc[i, :].index

    sns.barplot(
        x=df_pokemonsEvo.loc[i, :].values,
        y=estadisticas,
        hue=estadisticas,
        palette="Paired",
        dodge=False
    )

    plt.title(i)
    plt.xlim(0, 130)
    plt.xlabel("Mean Value")
    plt.ylabel("Stats")

    k += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# 30. Suma total de estadisticas de los pokemones agrupados por tipo

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 20))

k = 1

for i in stats:

    plt.subplot(3, 2, k)
    k += 1

    temp = df.reset_index()

    ax = sns.barplot(
        data=temp,
        x=i,
        y='Type',
        hue='Type',
        palette='plasma',
        legend=False
    )

    plt.title(f"Mean of total {i} for each type")
    plt.xlabel(i)
    plt.ylabel("Type")

plt.tight_layout()
plt.show()

# %% [markdown]
# Los 3 mejores tipos de Pokémon según la media total:
#
# Dragón
# Acero
# Volador

# %% [markdown]
# **Ejercicio 31:** Compara las graficas de las sumatorias vs Promedios de estadisticas en el segundo dataframe

# %% [markdown]
# **Conclusión:** graficar la media de los valores en lugar de los valores absolutos marca una gran diferencia.
#
# Respondamos a algunas preguntas:
#
# 1. ¿Cuál es la mejor estadística para cada tipo? (¿Cuál es la ventaja de cada tipo entre los 18 tipos? ; según el dataframe con las medias de la suma de las estadísticas)

# %%
print("--- MEJORES STATS: DATASET ORIGINAL ---")

best_stats = []

list_types = df.index

for tipo in list_types:
    best_stats.append(
        df.loc[tipo, :].sort_values(ascending=False).index[0]
    )

for tipo, mejor_stat in zip(list_types, best_stats):
    print(f'Best stat of type {tipo} is {mejor_stat}')
# Out:
# --- MEJORES STATS: DATASET ORIGINAL ---
# Best stat of type Artificial is Defense
# Best stat of type Bug is Attack
# Best stat of type Dark is Attack
# Best stat of type Dragon is Attack
# Best stat of type Electric is Sp. Atk
# Best stat of type Fairy is Sp. Def
# Best stat of type Fighting is Attack
# Best stat of type Fire is Sp. Atk
# Best stat of type Flying is Speed
# Best stat of type Ghost is Defense
# Best stat of type Grass is Sp. Atk
# Best stat of type Ground is Attack
# Best stat of type Ice is Sp. Atk
# Best stat of type Normal is HP
# Best stat of type Poison is Attack
# Best stat of type Psychic is Sp. Atk
# Best stat of type Rock is Defense
# Best stat of type Steel is Defense
# Best stat of type Water is Sp. Atk

# %%
print("\n--- MEJORES STATS: DATASET EVOLUCIONES ---")

best_stats_pokemonsEvo = []

num_cols = pokemonsEvo.select_dtypes(include='number')

for tipo in pokemonsEvo.index:
    mejor_stat = num_cols.loc[tipo].idxmax()
    best_stats_pokemonsEvo.append(mejor_stat)

for tipo, mejor_stat in zip(pokemonsEvo.index, best_stats_pokemonsEvo):
    print(f'Best stat of type {tipo} is {mejor_stat}')
# Out:
# --- MEJORES STATS: DATASET EVOLUCIONES ---
# Best stat of type 0 is Total
# Best stat of type 1 is Total
# Best stat of type 2 is Total
# Best stat of type 3 is Total
# Best stat of type 4 is Total
# Best stat of type 5 is Total
# Best stat of type 6 is Total
# Best stat of type 7 is Total
# Best stat of type 8 is Total
# Best stat of type 9 is Total
# Best stat of type 10 is Total
# Best stat of type 11 is Total
# Best stat of type 12 is Total
# Best stat of type 13 is Total
# Best stat of type 14 is Total
# Best stat of type 15 is Total
# Best stat of type 16 is Total
# Best stat of type 17 is Total
# Best stat of type 18 is Total
# Best stat of type 19 is Total
# Best stat of type 20 is Total
# Best stat of type 21 is Total
# Best stat of type 22 is Total
# Best stat of type 23 is Total
# Best stat of type 24 is Total
# Best stat of type 25 is Total
# Best stat of type 26 is Total
# Best stat of type 27 is Total
# Best stat of type 28 is Total
# Best stat of type 29 is Total
# ...

# %% [markdown]
# 32. Determinación de la Estadística más fuerte de cada tipo

# %%
pokemons[pokemons.Name.str.contains('Mega')]
# Out:
#        #                       Name      Type  Total   HP  Attack  Defense  \
# 4      3      VenusaurMega Venusaur     Grass    625   80     100      123
# 8      6  CharizardMega Charizard X      Fire    634   78     130      111
# 9      6  CharizardMega Charizard Y      Fire    634   78     104       78
# 13     9    BlastoiseMega Blastoise     Water    630   79     103      120
# 20    15      BeedrillMega Beedrill       Bug    495   65     150       40
# 24    18        PidgeotMega Pidgeot    Normal    579   83      80       80
# 73    65      AlakazamMega Alakazam   Psychic    590   55      50       65
# 89    80        SlowbroMega Slowbro     Water    590   95      75      180
# 104   94          GengarMega Gengar     Ghost    600   60      65       80
# 126  115  KangaskhanMega Kangaskhan    Normal    590  105     125      100
# 139  127          PinsirMega Pinsir       Bug    600   65     155      120
# ...

# %% [markdown]
# 33.Filtrado de Pokemones con Evolución de Nivel 4

# %%
pokemonsEvo[pokemonsEvo['Evolution']==4]
# Out:
#        #                       Name      Type  Total   HP  Attack  Defense  \
# 4      3      VenusaurMega Venusaur     Grass    625   80     100      123
# 8      6  CharizardMega Charizard X      Fire    634   78     130      111
# 9      6  CharizardMega Charizard Y      Fire    634   78     104       78
# 13     9    BlastoiseMega Blastoise     Water    630   79     103      120
# 20    15      BeedrillMega Beedrill       Bug    495   65     150       40
# 24    18        PidgeotMega Pidgeot    Normal    579   83      80       80
# 73    65      AlakazamMega Alakazam   Psychic    590   55      50       65
# 89    80        SlowbroMega Slowbro     Water    590   95      75      180
# 104   94          GengarMega Gengar     Ghost    600   60      65       80
# 126  115  KangaskhanMega Kangaskhan    Normal    590  105     125      100
# 139  127          PinsirMega Pinsir       Bug    600   65     155      120
# ...

# %%
mega_pokemons = ['Mega'+poke.split('Mega')[1] for poke in pokemons[pokemons.Name.str.contains('Mega')].Name]
mega_pokemons
# Out:
# ['Mega Venusaur',
#  'Mega Charizard X',
#  'Mega Charizard Y',
#  'Mega Blastoise',
#  'Mega Beedrill',
#  'Mega Pidgeot',
#  'Mega Alakazam',
#  'Mega Slowbro',
#  'Mega Gengar',
#  'Mega Kangaskhan',
#  'Mega Pinsir',
#  'Mega Gyarados',
#  'Mega Aerodactyl',
#  'Mega Mewtwo X',
#  'Mega Mewtwo Y',
#  'Meganium',
#  'Mega Ampharos',
#  'Mega Steelix',
#  'Mega Scizor',
#  'Mega Heracross',
#  'Mega Houndoom',
#  'Mega Tyranitar',
#  'Mega Sceptile',
#  'Mega Blaziken',
#  'Mega Swampert',
#  'Mega Gardevoir',
#  'Mega Sableye',
#  'Mega Mawile',
#  'Mega Aggron',
#  'Mega Medicham',
#  'Mega Manectric',
#  'Mega Sharpedo',
#  'Mega Camerupt',
#  'Mega Altaria',
#  'Mega Banette',
#  'Mega Absol',
#  'Mega Glalie',
#  'Mega Salamence',
#  'Mega Metagross',
#  'Mega Latias',
#  'Mega Latios',
#  'Mega Rayquaza',
#  'Mega Lopunny',
#  'Mega Garchomp',
#  'Mega Lucario',
#  'Mega Abomasnow',
#  'Mega Gallade',
#  'Mega Audino',
#  'Mega Diancie']

# %% [markdown]
# 34. Generación de Lista de los Pokemones con evolución mega.

# %%
mega_pokemonsEvo = ['Mega'+poke.split('Mega')[1] for poke in pokemonsEvo[pokemonsEvo.Evolution == 4].Name]
mega_pokemonsEvo
# Out:
# ['Mega Venusaur',
#  'Mega Charizard X',
#  'Mega Charizard Y',
#  'Mega Blastoise',
#  'Mega Beedrill',
#  'Mega Pidgeot',
#  'Mega Alakazam',
#  'Mega Slowbro',
#  'Mega Gengar',
#  'Mega Kangaskhan',
#  'Mega Pinsir',
#  'Mega Gyarados',
#  'Mega Aerodactyl',
#  'Mega Mewtwo X',
#  'Mega Mewtwo Y',
#  'Meganium',
#  'Mega Ampharos',
#  'Mega Steelix',
#  'Mega Scizor',
#  'Mega Heracross',
#  'Mega Houndoom',
#  'Mega Tyranitar',
#  'Mega Sceptile',
#  'Mega Blaziken',
#  'Mega Swampert',
#  'Mega Gardevoir',
#  'Mega Sableye',
#  'Mega Mawile',
#  'Mega Aggron',
#  'Mega Medicham',
#  'Mega Manectric',
#  'Mega Sharpedo',
#  'Mega Camerupt',
#  'Mega Altaria',
#  'Mega Banette',
#  'Mega Absol',
#  'Mega Glalie',
#  'Mega Salamence',
#  'Mega Metagross',
#  'Mega Latias',
#  'Mega Latios',
#  'Mega Rayquaza',
#  'Mega Lopunny',
#  'Mega Garchomp',
#  'Mega Lucario',
#  'Mega Abomasnow',
#  'Mega Gallade',
#  'Mega Audino',
#  'Mega Diancie']

# %%
# Reemplazo seguro de nombres Mega (si mega_pokemons está alineado correctamente)
pokemons['Name'] = pokemons['Name'].replace(
    pokemons[pokemons['Name'].str.contains('Mega', na=False)]['Name'].values,
    mega_pokemons
)

print("Which is the best pokemon for each type? (according to each stat)\n")

for tipo in list_types:
    print(f"TYPE {tipo.upper()}")

    df_tipo = pokemons[pokemons['Type'] == tipo]

    for stat in stats:
        if df_tipo.empty:
            continue

        best_pokemon = df_tipo.sort_values(by=stat, ascending=False)['Name'].iloc[0]

        print(f"Best {stat} pokemon is {best_pokemon}")

    print("*****************************************")
# Out:
# Which is the best pokemon for each type? (according to each stat)
#
# TYPE ARTIFICIAL
# *****************************************
# TYPE BUG
# Best HP pokemon is Yanmega
# Best Attack pokemon is Mega Heracross
# Best Defense pokemon is Shuckle
# Best Sp. Atk pokemon is Volcarona
# Best Sp. Def pokemon is Shuckle
# Best Speed pokemon is Ninjask
# *****************************************
# TYPE DARK
# Best HP pokemon is Yveltal
# Best Attack pokemon is Mega Absol
# Best Defense pokemon is Mega Sableye
# Best Sp. Atk pokemon is Mega Houndoom
# Best Sp. Def pokemon is Umbreon
# Best Speed pokemon is Darkrai
# *****************************************
# TYPE DRAGON
# Best HP pokemon is Kyurem
# Best Attack pokemon is Mega Rayquaza
# Best Defense pokemon is Mega Salamence
# Best Sp. Atk pokemon is Mega Rayquaza
# Best Sp. Def pokemon is Goodra
# Best Speed pokemon is Mega Salamence
# *****************************************
# TYPE ELECTRIC
# Best HP pokemon is Ampharos
# ...

# %% [markdown]
# 35. Identificación de mejor pokemon con mejor puntaje por estadisticas de cada grupo por tipo

# %%
print("Which is the best pokemon for each type? (according to each stat)\n")

for tipo in list_types:
    print(f"TYPE {tipo.upper()}")

    df_tipo = pokemonsEvo[pokemonsEvo['Type'] == tipo]

    for stat in stats:
        if df_tipo.empty:
            continue

        best_pokemon = df_tipo.loc[df_tipo[stat].idxmax(), 'Name']

        print(f"Best {stat} pokemon is {best_pokemon}")

    print("*****************************************")
# Out:
# Which is the best pokemon for each type? (according to each stat)
#
# TYPE ARTIFICIAL
# Best HP pokemon is Type: Null
# Best Attack pokemon is Magearna
# Best Defense pokemon is Cosmoem
# Best Sp. Atk pokemon is Magearna
# Best Sp. Def pokemon is Cosmoem
# Best Speed pokemon is Silvally
# *****************************************
# TYPE BUG
# Best HP pokemon is Yanmega
# Best Attack pokemon is HeracrossMega Heracross
# Best Defense pokemon is Shuckle
# Best Sp. Atk pokemon is Volcarona
# Best Sp. Def pokemon is Shuckle
# Best Speed pokemon is Ninjask
# *****************************************
# TYPE DARK
# Best HP pokemon is Yveltal
# Best Attack pokemon is AbsolMega Absol
# Best Defense pokemon is SableyeMega Sableye
# Best Sp. Atk pokemon is HoundoomMega Houndoom
# Best Sp. Def pokemon is Umbreon
# Best Speed pokemon is Weavile
# *****************************************
# TYPE DRAGON
# Best HP pokemon is Kyurem
# Best Attack pokemon is RayquazaMega Rayquaza
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.countplot(
    x='Generation',
    data=pokemons,
    hue='Generation',
    palette='seismic',
    legend=False
)

plt.title('Number of pokemons grouped by generation')
plt.ylabel('Number of pokemons')
plt.xlabel('Generation')

plt.show()

# %% [markdown]
# 36.Distribución de pokemon por generacion

# %%
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.countplot(
    x='Generation',
    data=pokemonsEvo,
    hue='Generation',
    palette='seismic',
    legend=False
)

plt.title('Number of pokemons (Evolutions) grouped by generation')
plt.ylabel('Number of pokemons')
plt.xlabel('Generation')

plt.show()

# %%
pokemons.groupby('Generation')[['#', 'Total', 'HP', 'Attack', 'Defense',
                                'Sp. Atk', 'Sp. Def', 'Speed', 'Legendary']].sum()
# Out:
#                 #  Total     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Generation
# 1           12646  71831  11071   12909    11906    12082    11639  12224
# 2           21442  44338   7548    7635     7779     6990     7834   6552
# 3           51879  70206  10737   13120    11926    12204    11466  10753
# 4           54444  56536   9029   10235     9612     9382     9512   8766
# 5           94755  71773  11845   13541    11934    11878    11342  11233
# 6           56417  35783   5598    6216     6288     6092     6141   5448
#
#             Legendary
# Generation
# 1                   6
# 2                   5
# 3                  18
# 4                  14
# 5                  15
# 6                   8

# %% [markdown]
# 37. Sumatoria de estadistica por generación

# %%
pokemonsEvo.groupby('Generation')[['#', 'Total', 'HP', 'Attack', 'Defense',
                                   'Sp. Atk', 'Sp. Def', 'Speed', 'Legendary','Evolution']].sum()
# Out:
#                 #  Total     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Generation
# 1           12646  71831  11071   12909    11906    12082    11639  12224
# 2           21442  44338   7548    7635     7779     6990     7834   6552
# 3           51879  70206  10737   13120    11926    12204    11466  10753
# 4           54444  56536   9029   10235     9612     9382     9512   8766
# 5           94755  71773  11845   13541    11934    11878    11342  11233
# 6           56417  35783   5598    6216     6288     6092     6141   5448
# 7            3620   2304    356     343      467      378      467    293
#
#             Legendary  Evolution
# Generation
# 1                   6        516
# 2                   5        322
# 3                  18        503
# 4                  14        374
# 5                  15        496
# 6                   8        247
# 7                   3          7

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 15))

k = 1

for i in stats:

    plt.subplot(3, 2, k)
    k += 1

    sns.swarmplot(
        x='Generation',
        y=i,
        data=pokemons,
        hue='Generation',   # <-- clave
        palette='plasma',
        legend=False,
        size=2
    )

    plt.title(f"{i} for each generation")

plt.tight_layout()
plt.show()

# %% [markdown]
# 38. Distrubucion de estadistica por generación

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 15))

k = 1

for i in stats:

    plt.subplot(3, 2, k)
    k += 1

    sns.swarmplot(
        x='Generation',
        y=i,
        data=pokemonsEvo,
        hue='Generation',
        palette='plasma',
        legend=False,
        size=2
    )

    plt.title(f"{i} for each generation")

plt.tight_layout()
plt.show()

# %%
k=1
plt.figure(figsize=(17,15))
for i in stats:
    plt.subplot(3,2,k)
    sns.boxplot(y=pokemons[i],x=pokemons.Generation)
    k=k+1
    plt.title(i+str(' for each generation'))

# %% [markdown]
# 39. Identificación de la concentración tendencia de datos por BoxPlots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

k = 1
plt.figure(figsize=(17, 15))

for i in stats:

    plt.subplot(3, 2, k)
    k += 1

    sns.boxplot(
        y=pokemonsEvo[i],
        x=pokemonsEvo['Generation']
    )

    plt.title(f"{i} for each generation")

plt.tight_layout()
plt.show()

# %% [markdown]
# 40. Histograma de estadistica por generación de pokemon

# %%
from bokeh.plotting import figure, show
from bokeh.layouts import gridplot

grouped = pokemons.groupby('Generation').sum()
generaciones = grouped.index.tolist()  

p1 = figure(width=400, height=200, title='HP for each generation')
p1.scatter(x=generaciones, y=grouped.HP, size=6, color='red')
p1.line(x=generaciones, y=grouped.HP, line_width=1, color='red')

p2 = figure(width=400, height=200, title='Attack for each generation')
p2.scatter(x=generaciones, y=grouped.Attack, size=6, color='red')
p2.line(x=generaciones, y=grouped.Attack, line_width=1, color='red')

p3 = figure(width=400, height=200, title='Defense for each generation')
p3.scatter(x=generaciones, y=grouped.Defense, size=6, color='red')
p3.line(x=generaciones, y=grouped.Defense, line_width=1, color='red')

p4 = figure(width=400, height=200, title='Sp. Atk for each generation')
p4.scatter(x=generaciones, y=grouped['Sp. Atk'], size=6, color='red')
p4.line(x=generaciones, y=grouped['Sp. Atk'], line_width=1, color='red')

p5 = figure(width=400, height=200, title='Sp. Def for each generation')
p5.scatter(x=generaciones, y=grouped['Sp. Def'], size=6, color='red')
p5.line(x=generaciones, y=grouped['Sp. Def'], line_width=1, color='red')

p6 = figure(width=400, height=200, title='Speed for each generation')
p6.scatter(x=generaciones, y=grouped.Speed, size=6, color='red')
p6.line(x=generaciones, y=grouped.Speed, line_width=1, color='red')
grid = gridplot([[p1, p2], [p3, p4], [p5, p6]])
show(grid)
# Out:
#   <div id="c9878301-0187-48d2-bcca-6cc009aa48b5" data-root-id="p2018" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, show
from bokeh.layouts import gridplot

grouped = pokemonsEvo.groupby('Generation').sum()
generaciones = grouped.index.tolist()  

p1 = figure(width=400, height=200, title='HP for each generation')
p1.scatter(x=generaciones, y=grouped.HP, size=6, color='red')
p1.line(x=generaciones, y=grouped.HP, line_width=1, color='red')

p2 = figure(width=400, height=200, title='Attack for each generation')
p2.scatter(x=generaciones, y=grouped.Attack, size=6, color='red')
p2.line(x=generaciones, y=grouped.Attack, line_width=1, color='red')

p3 = figure(width=400, height=200, title='Defense for each generation')
p3.scatter(x=generaciones, y=grouped.Defense, size=6, color='red')
p3.line(x=generaciones, y=grouped.Defense, line_width=1, color='red')

p4 = figure(width=400, height=200, title='Sp. Atk for each generation')
p4.scatter(x=generaciones, y=grouped['Sp. Atk'], size=6, color='red')
p4.line(x=generaciones, y=grouped['Sp. Atk'], line_width=1, color='red')

p5 = figure(width=400, height=200, title='Sp. Def for each generation')
p5.scatter(x=generaciones, y=grouped['Sp. Def'], size=6, color='red')
p5.line(x=generaciones, y=grouped['Sp. Def'], line_width=1, color='red')

p6 = figure(width=400, height=200, title='Speed for each generation')
p6.scatter(x=generaciones, y=grouped.Speed, size=6, color='red')
p6.line(x=generaciones, y=grouped.Speed, line_width=1, color='red')
grid = gridplot([[p1, p2], [p3, p4], [p5, p6]])
show(grid)
# Out:
#   <div id="bb0afcd7-8627-498f-ab5a-468ee9fb3c78" data-root-id="p1677" style="display: contents;"></div>

# %% [markdown]
# 41. Cantidad de Pokemones Legendarios por generacion

# %%
len(pokemons[pokemons.Legendary==True])
# There are 65 Legendary pokemons
# 8.125% pokemons are Legendary
# Out:
# 66

# %% [markdown]
# 42. Distribución de totales de pokemones Legendarios por generacion

# %%
pokemons.groupby('Generation').sum().Legendary
# Generations 3 ,5 & 4 have the most legendary pokemons
# Out:
# Generation
# 1     6
# 2     5
# 3    18
# 4    14
# 5    15
# 6     8
# Name: Legendary, dtype: int64

# %% [markdown]
# 43. Comparación de pokemones Legendarios por Generación

# %%
import seaborn as sns
import matplotlib.pyplot as plt

legendary_by_gen = pokemons.groupby('Generation')['Legendary'].sum()

plt.figure(figsize=(8,5))

sns.barplot(
    x=legendary_by_gen.index,
    y=legendary_by_gen.values,
    hue=legendary_by_gen.index,   # ✔ obligatorio en versiones nuevas
    palette='CMRmap',
    legend=False
)

plt.title('Number of Legendary Pokémon per Generation')
plt.xlabel('Generation')
plt.ylabel('Legendary Pokémon')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

legendary_by_gen = pokemonsEvo.groupby('Generation')['Legendary'].sum()

plt.figure(figsize=(8,5))

sns.barplot(
    x=legendary_by_gen.index,
    y=legendary_by_gen.values,
    hue=legendary_by_gen.index,   # ✔ obligatorio en versiones nuevas
    palette='CMRmap',
    legend=False
)

plt.title('Number of Legendary Pokémon per Generation')
plt.xlabel('Generation')
plt.ylabel('Legendary Pokémon')

plt.show()

# %% [markdown]
# 44. Conteo de Pokemones Legendarios por Tipo

# %%
pokemons.groupby('Type').sum().Legendary.sort_values(ascending=False)
# Out:
# Type
# Psychic     14
# Dragon      12
# Water        5
# Fire         5
# Ground       4
# Electric     4
# Steel        4
# Rock         4
# Grass        3
# Dark         2
# Ghost        2
# Ice          2
# Normal       2
# Flying       2
# Fairy        1
# Poison       0
# Fighting     0
# Bug          0
# Name: Legendary, dtype: int64

# %%
pokemonsEvo.groupby('Type').sum().Legendary.sort_values(ascending=False)
# Out:
# Type
# Psychic       14
# Dragon        12
# Water          5
# Fire           5
# Steel          4
# Electric       4
# Rock           4
# Ground         4
# Grass          3
# Artificial     3
# Flying         2
# Ice            2
# Normal         2
# Dark           2
# Ghost          2
# Fairy          1
# Bug            0
# Poison         0
# Fighting       0
# Name: Legendary, dtype: int64

# %% [markdown]
# 45. Gráfica de Barras de Pokemones Legendarios por Tipo

# %%
import matplotlib.pyplot as plt
import seaborn as sns

legendary_by_type = (
    pokemons.groupby('Type')['Legendary']
    .sum()
    .sort_values(ascending=False)
)

plt.figure(figsize=(15,10))

sns.barplot(
    x=legendary_by_type.index,
    y=legendary_by_type.values,
    hue=legendary_by_type.index,
    palette='Paired',
    legend=False
)

plt.title('Legendary Pokémon by Type')
plt.xlabel('Type')
plt.ylabel('Number of Legendary Pokémon')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

legendary_by_type = (
    pokemonsEvo.groupby('Type')['Legendary']
    .sum()
    .sort_values(ascending=False)
)

plt.figure(figsize=(15,10))

sns.barplot(
    x=legendary_by_type.index,
    y=legendary_by_type.values,
    hue=legendary_by_type.index,
    palette='Paired',
    legend=False
)

plt.title('Legendary Pokémon by Type')
plt.xlabel('Type')
plt.ylabel('Number of Legendary Pokémon')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 46. Comparación de Estadísticas de Pokemones Legendarios por Tipo

# %%
import matplotlib.pyplot as plt
import seaborn as sns

k = 1

plt.figure(figsize=(15,30))

for i in stats:

    plt.subplot(6,1,k)
    k += 1

    sns.swarmplot(
        x='Type',
        y=i,
        data=pokemons,
        hue='Legendary',
        palette='Dark2',
        size=2
    )

    plt.title(f"Total of {i} for each type")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

k = 1

plt.figure(figsize=(15,30))

for i in stats:

    plt.subplot(6,1,k)
    k += 1

    sns.swarmplot(
        x='Type',
        y=i,
        data=pokemonsEvo,
        hue='Legendary',
        palette='Dark2',
        size=2
    )

    plt.title(f"Total of {i} for each type")

plt.tight_layout()
plt.show()

# %% [markdown]
# 47. Comparación de Estadísitcas de Pokemones por Tipo enfocado en Legendarios

# %%
plt.figure(figsize=(17, 22))
k = 1

for tipo in list_types:
    datos_tipo = pok_melt[pok_melt['Type'] == tipo]

    plt.subplot(6, 3, k)
    k += 1

    sns.stripplot(
        data=datos_tipo,
        x='variable',
        y='value',
        hue='Legendary',
        palette='Dark2',
        jitter=0.25,
        dodge=True,
        size=3,
        alpha=0.7
    )

    plt.title(tipo)
    plt.xlabel('')
    plt.ylabel('Valor')

    plt.legend(
        bbox_to_anchor=(0, 1.02, 1, 0.102),
        loc='lower left',
        ncol=2,
        mode='expand',
        borderaxespad=0
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# 48. Análisis de Pokemones Legendarios vs Normales

# %%
legend=pokemons[pokemons.Legendary==True]
for i in stats:
    print('Number of legendary pokemons with ',i, ' higher than the average:',
          len(legend[legend[i]>pokemons[i].mean()]),'\nPercentage:', round(len(legend[legend[i]>pokemons[i].mean()])/65*100,2),
           '\n**************')
# Out:
# Number of legendary pokemons with  HP  higher than the average: 60
# Percentage: 92.31
# **************
# Number of legendary pokemons with  Attack  higher than the average: 60
# Percentage: 92.31
# **************
# Number of legendary pokemons with  Defense  higher than the average: 55
# Percentage: 84.62
# **************
# Number of legendary pokemons with  Sp. Atk  higher than the average: 62
# Percentage: 95.38
# **************
# Number of legendary pokemons with  Sp. Def  higher than the average: 62
# Percentage: 95.38
# **************
# Number of legendary pokemons with  Speed  higher than the average: 61
# Percentage: 93.85
# **************

# %%
legend=pokemonsEvo[pokemonsEvo.Legendary==True]
for i in stats:
    print('Number of legendary pokemons with ',i, ' higher than the average:',
          len(legend[legend[i]>pokemonsEvo[i].mean()]),'\nPercentage:', round(len(legend[legend[i]>pokemonsEvo[i].mean()])/65*100,2),
           '\n**************')
# Out:
# Number of legendary pokemons with  HP  higher than the average: 61
# Percentage: 93.85
# **************
# Number of legendary pokemons with  Attack  higher than the average: 61
# Percentage: 93.85
# **************
# Number of legendary pokemons with  Defense  higher than the average: 57
# Percentage: 87.69
# **************
# Number of legendary pokemons with  Sp. Atk  higher than the average: 63
# Percentage: 96.92
# **************
# Number of legendary pokemons with  Sp. Def  higher than the average: 63
# Percentage: 96.92
# **************
# Number of legendary pokemons with  Speed  higher than the average: 61
# Percentage: 93.85
# **************

# %% [markdown]
# 49. Matríz de Corelación de las Estadísitca de los pokemones mendiante un mapa de calor (HeatMap)

# %%
# Seleccionar únicamente columnas numéricas
datos_numericos = pokemons.select_dtypes(include='number')

# Eliminar la columna identificadora si existe
datos_numericos = datos_numericos.drop(columns=['#'], errors='ignore')

plt.figure(figsize=(15, 10))

sns.heatmap(
    datos_numericos.corr(),
    annot=True,
    cmap='YlGnBu',
    fmt='.2f'
)

plt.title('Matriz de correlación de las estadísticas de los Pokémon')
plt.show()

# %%
# Seleccionar únicamente columnas numéricas
datos_numericos = pokemonsEvo.select_dtypes(include='number')

# Eliminar la columna identificadora si existe
datos_numericos = datos_numericos.drop(columns=['#'], errors='ignore')

plt.figure(figsize=(15, 10))

sns.heatmap(
    datos_numericos.corr(),
    annot=True,
    cmap='YlGnBu',
    fmt='.2f'
)

plt.title('Matriz de correlación de las estadísticas de los Pokémon')
plt.show()

# %% [markdown]
# 50. Matríz de Disperción de las Caraterísticas de los Pokemones

# %%
sns.pairplot(pokemons.drop(['#','Legendary','Generation'],axis=1))

# %%
sns.pairplot(pokemonsEvo.drop(['#','Legendary','Generation'],axis=1))
